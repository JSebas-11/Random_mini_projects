# %% [markdown]
# Script usado para limpieza de datos, con el fin de cargar el dataset default en formato csv
# sin datos nulos, duplicados, etc para la lista doblemente enlazada de c++

# %%
import pandas as pd
import re

# %%
#Cargar dataset
df: pd.DataFrame = pd.read_csv("origVGsales.csv", sep=",")

#Modificar la cantidad de elementos a mostrar en pantalla
pd.set_option("display.max.rows", df.shape[0])

# %%
#Buscar mediante expresiones regulares las columnas que tengan ventas
# para ser borradas ya que no nos interesan para nuestro proyecto  
toDelete: list[str] = [col for col in df.columns if re.match(r"\w*\_?sales", col, re.IGNORECASE)] 
print(f"These columns will be deleted: {toDelete}")
df.drop(columns=toDelete, inplace=True)
# Out:
# These columns will be deleted: ['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales']

# %%
#Buscar juegos con nombres duplicados para ser borrados ya que no son permitidos
duplicates: pd.DataFrame = df[df.duplicated(['Name'])]
df.drop_duplicates(['Name'], inplace=True)

#Borrar filas con campos null
df.dropna(inplace=True)

duplicates #Columnas duplicadas borradas
# Out:
#      Rank                            Name Platform    Year    Genre  \
# 16     41         Call of Duty: Black Ops      PS3  2010.0  Shooter
# 43    104                   Battlefield 3      PS3  2011.0  Shooter
# 54    121  Call of Duty 4: Modern Warfare      PS3  2007.0  Shooter
# 65    135             Red Dead Redemption     X360  2010.0   Action
# 72    156                          Tetris      NES  1988.0   Puzzle
# 109   695                     Dead Island      PS3  2011.0   Action
#
#                 Publisher
# 16             Activision
# 43        Electronic Arts
# 54             Activision
# 65   Take-Two Interactive
# 72               Nintendo
# 109           Deep Silver

# %%
#Crear dos columnas para verificar el tamaño de los strings
df['NameSize'] = df['Name'].apply(lambda name:len(name))
df['PublisherSize'] = df['Publisher'].apply(lambda name:len(name))

#Rows con tamaño de string superior al tamaño de formato impuesto
notAllow = df[(df['NameSize'] > 32) | (df['PublisherSize'] > 32)]

#Borrar filas con exceso de tamaño
df.drop(index=notAllow.index, inplace=True)

notAllow #Columnas borradas
# Out:
#      Rank                                        Name Platform    Year  \
# 37     95        The Legend of Zelda: Ocarina of Time      N64  1998.0
# 38     96      Crash Bandicoot 2: Cortex Strikes Back       PS  1997.0
# 41    101      The Legend of Zelda: Twilight Princess      Wii  2006.0
# 68    147                              The Last of Us      PS3  2013.0
# 74    160                         Batman: Arkham City      PS3  2011.0
# 84    250   Winning Eleven: Pro Evolution Soccer 2007      PS2  2006.0
# 97    407  Star Wars Episode III: Revenge of the Sith      PS2  2005.0
# 103   509                               Mortal Kombat      PS3  2011.0
# 105   554                             Mortal Kombat X      PS4  2015.0
# 123  1124                                  Until Dawn      PS4  2015.0
#
#          Genre                               Publisher  NameSize  \
# 37      Action                                Nintendo        36
# 38    Platform             Sony Computer Entertainment        38
# 41      Action                                Nintendo        38
# 68      Action      Sony Computer Entertainment Europe        14
# 74      Action  Warner Bros. Interactive Entertainment        19
# 84      Sports            Konami Digital Entertainment        41
# 97      Action                               LucasArts        42
# 103   Fighting  Warner Bros. Interactive Entertainment        13
# 105   Fighting  Warner Bros. Interactive Entertainment        15
# 123  Adventure      Sony Computer Entertainment Europe        10
#
#      PublisherSize
# 37               8
# 38              27
# 41               8
# 68              34
# 74              38
# 84              28
# 97               9
# 103             38
# 105             38
# 123             34

# %%
#Ordenar el dataset para adecuarse al formato requerido, ademas de reinciar indices
df = df[['Name','Genre', 'Platform', 'Publisher', 'Year']].reset_index(drop=True)

#Columna nombres tiene tipo float asi que la convertimos a entero
df['Year'] = df['Year'].astype("int32")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       108 non-null    object
#  1   Genre      108 non-null    object
#  2   Platform   108 non-null    object
#  3   Publisher  108 non-null    object
#  4   Year       108 non-null    int32
# dtypes: int32(1), object(4)
# memory usage: 3.9+ KB

# %%
df.to_csv("preloaded.csv", sep=";", index=False)

#Final dataset exported
df
# Out:
#                                Name         Genre Platform  \
# 0                        Wii Sports        Sports      Wii
# 1                 Super Mario Bros.      Platform      NES
# 2                    Mario Kart Wii        Racing      Wii
# 3                            Tetris        Puzzle       GB
# 4                     Mario Kart DS        Racing       DS
# 5                Grand Theft Auto V        Action      PS3
# 6     Grand Theft Auto: San Andreas        Action      PS2
# 7                 Super Mario World      Platform     SNES
# 8               Super Mario Bros. 3      Platform      NES
# 9       Grand Theft Auto: Vice City        Action      PS2
# 10           Gran Turismo 3: A-Spec        Racing      PS2
# 11   Call of Duty: Modern Warfare 3       Shooter     X360
# 12          Call of Duty: Black Ops       Shooter     X360
# 13       Call of Duty: Black Ops II       Shooter     X360
# 14             Grand Theft Auto III        Action      PS2
# 15          Super Smash Bros. Brawl      Fighting      Wii
# 16      Animal Crossing: Wild World    Simulation       DS
# 17                     Mario Kart 7        Racing      3DS
# 18                           Halo 3       Shooter     X360
# 19                   Super Mario 64      Platform      N64
# 20                   Gran Turismo 4        Racing      PS2
# 21              Grand Theft Auto IV        Action     X360
# 22                     Just Dance 3          Misc      Wii
# 23             Call of Duty: Ghosts       Shooter     X360
# 24                      Halo: Reach       Shooter     X360
# 25                           Halo 4       Shooter     X360
# 26   Call of Duty 4: Modern Warfare       Shooter     X360
# 27                          FIFA 16        Sports      PS4
# 28                           Halo 2       Shooter       XB
# 29                    Mario Party 8          Misc      Wii
# 30                   FIFA Soccer 13        Action      PS3
# 31                       The Sims 3    Simulation       PC
# 32                    GoldenEye 007       Shooter      N64
# 33                  Final Fantasy X  Role-Playing      PS2
# 34                          Pac-Man        Puzzle     2600
# 35     Star Wars Battlefront (2015)       Shooter      PS4
# 36       Call of Duty: World at War       Shooter     X360
# 37                    Battlefield 3       Shooter     X360
# 38        Call of Duty: Black Ops 3       Shooter     XOne
# 39       Need for Speed Underground        Racing      PS2
# 40                         Tekken 3      Fighting       PS
# 41                        Fallout 4  Role-Playing      PS4
# 42                          FIFA 14        Sports      PS3
# 43     Need for Speed Underground 2        Racing      PS2
# 44        Medal of Honor: Frontline       Shooter      PS2
# 45   Uncharted 3: Drake's Deception        Action      PS3
# 46                  Crash Bandicoot      Platform       PS
# 47                   Gears of War 2       Shooter     X360
# 48       Uncharted 2: Among Thieves        Action      PS3
# 49                          FIFA 12        Sports      PS3
# 50                Big Brain Academy          Misc       DS
# 51              Red Dead Redemption        Action      PS3
# 52                          FIFA 15        Sports      PS4
# 53      Donkey Kong Country Returns      Platform      Wii
# 54      The Elder Scrolls V: Skyrim  Role-Playing      PS3
# 55              The Legend of Zelda        Action      NES
# 56             Assassin's Creed III        Action      PS3
# 57             Halo: Combat Evolved       Shooter       XB
# 58          Pokémon Emerald Version  Role-Playing      GBA
# 59                World of Warcraft  Role-Playing       PC
# 60                     Gears of War       Shooter     X360
# 61                Final Fantasy XII  Role-Playing      PS2
# 62                  Resident Evil 2        Action       PS
# 63                          Destiny       Shooter      PS4
# 64                 Assassin's Creed     Adventure     X360
# 65               Forza Motorsport 3        Racing     X360
# 66                       Diablo III  Role-Playing       PC
# 67                        Fable III  Role-Playing     X360
# 68       Microsoft Flight Simulator    Simulation       PC
# 69                   Guitar Hero II          Misc      PS2
# 70           Tony Hawk's Pro Skater        Sports       PS
# 71                          FIFA 17        Sports      PS4
# 72                      Tomb Raider        Action       PS
# 73   The Elder Scrolls IV: Oblivion  Role-Playing     X360
# 74      Need for Speed: Most Wanted        Racing      PS2
# 75                        Far Cry 4       Shooter      PS4
# 76                    Left 4 Dead 2       Shooter     X360
# 77                         NBA 2K16        Sports      PS4
# 78                  Resident Evil 4        Action      PS2
# 79        Tom Clancy's The Division       Shooter      PS4
# 80           Star Wars: Battlefront       Shooter      PS2
# 81           Doom II: Hell on Earth       Shooter       PC
# 82                        Far Cry 3       Shooter      PS3
# 83                 Monster Hunter 4  Role-Playing      3DS
# 84                      Borderlands       Shooter     X360
# 85                        Max Payne       Shooter      PS2
# 86                       L.A. Noire     Adventure      PS3
# 87                    Mass Effect 2  Role-Playing     X360
# 88                     Saints Row 2        Action     X360
# 89                           Rayman      Platform       PS
# 90                          Metroid        Action      NES
# 91                       Ice Hockey        Sports      NES
# 92        Pro evolution soccer 2011        Sports      PS3
# 93                      Dead Island        Action     X360
# 94                   Tomb Raider II        Action       PC
# 95            God of War: Ascension        Action      PS3
# 96                       BioShock 2       Shooter     X360
# 97                         Portal 2       Shooter     X360
# 98                       Dead Space        Action      PS3
# 99                    Forza Horizon        Racing     X360
# 100         Dragon Age: Inquisition  Role-Playing      PS4
# 101                    Just Cause 3        Action      PS4
# 102               BioShock Infinite       Shooter      PS3
# 103              Hitman: Absolution        Action     X360
# 104                       Crackdown       Shooter     X360
# 105                   Saints Row IV        Action     X360
# 106                     Max Payne 3       Shooter     X360
# 107                     Viva Pinata    Simulation     X360
#
#                         Publisher  Year
# 0                        Nintendo  2006
# 1                        Nintendo  1985
# 2                        Nintendo  2008
# 3                        Nintendo  1989
# 4                        Nintendo  2005
# 5            Take-Two Interactive  2013
# 6            Take-Two Interactive  2004
# 7                        Nintendo  1990
# 8                        Nintendo  1988
# 9            Take-Two Interactive  2002
# 10    Sony Computer Entertainment  2001
# 11                     Activision  2011
# 12                     Activision  2010
# 13                     Activision  2012
# 14           Take-Two Interactive  2001
# 15                       Nintendo  2008
# 16                       Nintendo  2005
# 17                       Nintendo  2011
# 18         Microsoft Game Studios  2007
# 19                       Nintendo  1996
# 20    Sony Computer Entertainment  2004
# 21           Take-Two Interactive  2008
# 22                        Ubisoft  2011
# 23                     Activision  2013
# 24         Microsoft Game Studios  2010
# 25         Microsoft Game Studios  2012
# 26                     Activision  2007
# 27                Electronic Arts  2015
# 28         Microsoft Game Studios  2004
# 29                       Nintendo  2007
# 30                Electronic Arts  2012
# 31                Electronic Arts  2009
# 32                       Nintendo  1997
# 33    Sony Computer Entertainment  2001
# 34                          Atari  1982
# 35                Electronic Arts  2015
# 36                     Activision  2008
# 37                Electronic Arts  2011
# 38                     Activision  2015
# 39                Electronic Arts  2003
# 40    Sony Computer Entertainment  1998
# 41             Bethesda Softworks  2015
# 42                Electronic Arts  2013
# 43                Electronic Arts  2004
# 44                Electronic Arts  2002
# 45    Sony Computer Entertainment  2011
# 46    Sony Computer Entertainment  1996
# 47         Microsoft Game Studios  2008
# 48    Sony Computer Entertainment  2009
# 49                Electronic Arts  2011
# 50                       Nintendo  2005
# 51           Take-Two Interactive  2010
# 52                Electronic Arts  2014
# 53                       Nintendo  2010
# 54             Bethesda Softworks  2011
# 55                       Nintendo  1986
# 56                        Ubisoft  2012
# 57         Microsoft Game Studios  2001
# 58                       Nintendo  2004
# 59                     Activision  2004
# 60         Microsoft Game Studios  2006
# 61                    Square Enix  2006
# 62             Virgin Interactive  1998
# 63                     Activision  2014
# 64                        Ubisoft  2007
# 65         Microsoft Game Studios  2009
# 66                     Activision  2012
# 67         Microsoft Game Studios  2010
# 68         Microsoft Game Studios  1996
# 69                      RedOctane  2006
# 70                     Activision  1999
# 71                Electronic Arts  2016
# 72              Eidos Interactive  1996
# 73           Take-Two Interactive  2006
# 74                Electronic Arts  2005
# 75                        Ubisoft  2014
# 76                Electronic Arts  2009
# 77           Take-Two Interactive  2015
# 78                         Capcom  2005
# 79                        Ubisoft  2016
# 80                      LucasArts  2004
# 81             Virgin Interactive  1994
# 82                        Ubisoft  2012
# 83                         Capcom  2013
# 84           Take-Two Interactive  2009
# 85           Take-Two Interactive  2001
# 86           Take-Two Interactive  2011
# 87                Electronic Arts  2010
# 88                            THQ  2008
# 89                        Ubisoft  1995
# 90                       Nintendo  1986
# 91                       Nintendo  1988
# 92   Konami Digital Entertainment  2010
# 93                    Deep Silver  2011
# 94              Eidos Interactive  1997
# 95    Sony Computer Entertainment  2013
# 96           Take-Two Interactive  2010
# 97                 Valve Software  2011
# 98                Electronic Arts  2008
# 99         Microsoft Game Studios  2012
# 100               Electronic Arts  2014
# 101                   Square Enix  2015
# 102          Take-Two Interactive  2013
# 103                   Square Enix  2012
# 104        Microsoft Game Studios  2007
# 105                   Deep Silver  2013
# 106          Take-Two Interactive  2012
# 107        Microsoft Game Studios  2006
